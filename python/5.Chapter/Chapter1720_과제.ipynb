# %% [markdown]
# 안녕하세요. 수강생 여러분~! Chapter17 ~ 20 수업은 잘 들으셨나요?
#
# Chapter17 ~ 20의 수업 내용을 바탕으로 아래 문제를 풀어주시면 됩니다.
#
# [**답변 입력 방법**]
#
# 문제 아래에 있는 코드 입력창에 정답코드를 작성하신 후 ▷ 버튼을 클릭해 코드를 실행해보세요<br>

# %% [markdown]
# [문제1]
#
# print_even 리스트 내에 있는 값 중 짝수만 화면에 출력되도록 print_score 함수를 생성 후 결과값을 출력해주세요
#
# print_even ([1, 3, 2, 10, 12, 11, 15])

# %%
def print_even(numbers):
    for number in numbers:
        if number % 2 == 0:
            print(number)

 
print_even(numbers)
# Out:
# 2
# 10
# 12

# %% [markdown]
# ---

# %% [markdown]
# [문제2]
#
# 비어있는 오즈 (oz) 클래스를 "정의" 해보세요.

# %%
class OZ:
    pass
obj = OZ()

obj.attribute = "HelloWorld"

print(obj.attribute)
# Out:
# HelloWorld

# %% [markdown]
# ---

# %% [markdown]
# [문제3]
#
# 오즈(oz) 클래스의 인스턴스를 "생성" 하고 이를 coding 변수로 할당해보세요.

# %%
class OZ:
    def __init__(self, name):
        self.hello = '안녕하세요'
        self.name = name

    def greeting(self):
        print('{0} 저는 {1}입니다.'.format(self.hello, self.name))

coding = OZ('coding')
coding.greeting()
# Out:
# 안녕하세요 저는 coding입니다.

# %% [markdown]
# ---

# %% [markdown]
# [문제4]
#
# 오즈(oz) 클래스에 "클래스 정복"을 출력하는 기본 생성자를 추가해주세요

# %%
class OZ:
    def __init__(self, name):
        self.hello = '안녕하세요'
        self.name = name

    def greeting(self):
        print('{0} 저는 {1}입니다.'.format(self.hello, self.name))

coding = OZ('coding 클래스 정복자')
coding.greeting()
# Out:
# 안녕하세요 저는 coding 클래스 정복자입니다.

# %% [markdown]
# ---

# %% [markdown]
# [문제5]
#
# 오즈 (oz) 클래스에 (이름, 나이, 코딩레벨)을 받는 생성자를 추가해주세요
#
# coding = oz("김코", 30, "A")

# %%
class OZ:
    def __init__(self, name, age, codelevel):
        self.hello = '안녕하세요'
        self.name = name
        self.age = age
        self.codelevel = codelevel

    def greeting(self):
        print('coding = {1}, {2}. {3}'.format(self.hello, self.name, self.age, self.codelevel))

coding = OZ('coding', 27, 'C')
coding.greeting()
# Out:
# coding = coding, 27. C

# %% [markdown]
# ---

# %% [markdown]
# [문제6]
#
# 5번 문제에서 생성한 인스턴스의 이름, 나이, 성별을 출력해주세요.
# 인스턴스 변수에 접근하여 값을 출력하면 됩니다  : )
#
# 출력 결과
# 이름 : 김코
# 나이 : 30
# 코딩레벨 : A

# %%
class OZ:
    def __init__(self, name, age, codelevel):
        self.hello = '안녕하세요'
        self.name = name
        self.age = age
        self.codelevel = codelevel

    def greeting(self):
        print('coding = {1}, {2}. {3}'.format(self.hello, self.name, self.age, self.codelevel))


coding = OZ('coding', 27, 'C')
coding.greeting()


print('이름 :', coding.name)
print('나이 :', coding.age)
print('코딩레벨 :', coding.codelevel)
# Out:
# coding = coding, 27. C
# 이름 : coding
# 나이 : 27
# 코딩레벨 : C

# %% [markdown]
# ---

# %% [markdown]
# [뮨제7]
#
# 오즈 (oz) 클래스에서 이름, 나이, 성별을 출력하는 who() 메소드를 추가하고 who()메소드를 이용해 아래 출력 결과를 만들어주세요
#
#
# 출력 결과 : 이름: 김코, 나이: 30, 코딩레벨: A

# %%
class OZ:
    def __init__(self, name, age, codelevel):
        self.hello = '안녕하세요'
        self.name = name
        self.age = age
        self.codelevel = codelevel

    def greeting(self):
        print('coding = {1}, {2}. {3}'.format(self.hello, self.name, self.age, self.codelevel))

    def who(self):
        print(f'이름: {self.name}, 나이: {self.age}, 코딩레벨: {self.codelevel}')

# coding = OZ('coding', 27, 'C')
# coding.greeting()
coding.who()

# print('이름 :', coding.name)
# print('나이 :', coding.age)
# print('코딩레벨 :', coding.codelevel)
# Out:
# 이름: coding, 나이: 27, 코딩레벨: C

# %% [markdown]
# #### 리팩토링 과제
#
# Day4에서 만든 "붕어빵 자동 판매 시스템"은 절차적 코드로 구현되어있습니다.
#
# Day5에서 배운 함수, 클래스 개념을 적용시켜 객체지향적으로 리팩토링을 진행해주세요

# %%
# # 리팩토링 과제 힌트
# # 구조는 아래와 같습니다.
# class BungeoppangShop:
#     def __init__(self):

#     def check_stock(self):

#     def process_order(self, bread_type, bread_count):

#     def admin_mode(self):

#     def calculate_total_sales(self):

# def main():

# if __name__ == "__main__":
#     main()

# ###############4일차_과제#####################

# # 외부 함수 
# stock = {
#     "팥붕어빵" : 10,
#     "슈크림붕어빵" : 8,
#     "초코붕어빵" : 5
# }

# prices = {
#     "팥붕어빵" : 1000,
#     "슈크림붕어빵" : 1200,
#     "초코붕어빵": 15000
# }

# sales = {
#     "팥붕어빵": 0,
#     "슈크림붕어빵": 0,
#     "초코붕어빵": 0
# }

# while True:
#     mode = input("원하는 모드를 선택하세요(주문, 관리자, 종료) :")
#     if mode == "종료":
#         break


#     if mode == "관리자":
#         while True:
#             bread_type = input("추가할 붕어빵 종류를 입력하세요 (팥붕어빵, 슈크림붕어빵, 초코붕어빵). 종료를 원하시면 '종료' 입력하세요 : ")
#             if bread_type == "종료":
#                 break
#             additional_stock = int(input(f"{bread_type}의 추가할 개수를 입력하세요"))
#             stock[bread_type] += additional_stock
#             print(f"{bread_type}의 재고가 {additional_stock}개 추가되었습니다.")
#             print("현재 붕어빵 재고 :")
#             for bread, quantity in stock.items():
#                 print(f"{bread}: {quantity}")

    
#     if mode == "주문":
#         while True:
#             bread_type = input("주문한 붕어빵 종류를 입력하세요 (팥붕어빵, 슈크림붕어빵, 초코붕어빵) 종료를 원하시면 '종료'를 입력하세요")
#             if bread_type == "종료":
#                 break
#             bread_count = int(input("주문할 붕어빵 개수를 입력해주세요 :"))

#             if stock[bread_type]  >= bread_count:
#                 stock[bread_type] -= bread_count
#                 sales[bread_type] += bread_count
#                 print(f"{bread_type} {bread_count}개를 판매했습니다.")
#             else:
#                 print(f"죄송합니다. {bread_type} 재고가 부족합니다.")
            
#             print(f"현재 붕어빵 재고:")
#             for bread, quantity in stock.items():
#                 print(f"{bread}: {quantity}")


#     print("주문이 종료되었습니다.")
#     total_sales =sum(sales[b] * prices[b]for b in sales)
#     print(f"총 매출 : {total_sales}원")
#     print("모든 거래 내역:")
#     print('\n'.join([f"{b} 판매 : {sales[b]}개, 매출: {sales[b]*prices[b]}원" for b in sales]))

# %% [markdown]
# 과제_1: BungeoppangShop 클래스 만들기
#
# - __init__: 초기 재고, 가격, 판매량을 설정합니다.
# - check_stock: 현재 재고를 출력합니다.
# - process_order: 주문을 처리하고 재고를 업데이트합니다.
# - admin_mode: 관리자 모드에서 재고를 추가합니다.
# - calculate_total_sales: 총 매출을 계산하고 출력합니다.

# %%
class BungeoppangShop:
    def __init__(self,stock,price,sales):
        self.stock = stock
        self.price = price
        self.sales = sales
        self.order_list ={}

    def check_stock(self):
        now_stock = print(f"현재 재고 : {self.stock}")
        return(now_stock)
    
    def process_order(self):
        print("<주문 모드>")
        while True:
            self.bread_type = input("주문하실 붕어빵 종류를 입력해주세요 :")
            if self.bread_type == "종료":
                break
            elif self.bread_type not in self.stock:
                print("잘못된 값을 입력했습니다. 모드를 종료합니다.")
                break

            self.bread_count = input("주문하실 붕어빵 개수를 입력해주세요 :")
            if self.bread_count == "종료":
                break
            
            try:
                self.bread_count = int(self.bread_count)       
            except ValueError:
                print("잘못된 값을 입력하셨습니다. 모드를 종료합니다.")
                break
            
            self.order_list[self.bread_type] = self.bread_count # :)

            if self.stock[self.bread_type] >= int(self.order_list[self.bread_type]):
                self.stock[self.bread_type] -= int(self.order_list[self.bread_type])
            elif self.stock[self.bread_type] < int(self.order_list[self.bread_type]):
                print("재고가 부족합니다. 모드를 종료합니다.")
                break
        
        print("=" * 50)
        print(f"주문하신 내용은 : {self.order_list}입니다.")
        print(f"현재 재고는 : {self.stock}입니다.")
        print("=" * 50)
        
    def admin_mode(self):
        print("<관리자 모드>")
        while True:
            
            self.bread_type = input("추가할 붕어빵 종류를 입력해주세요 :")
            if self.bread_type == "종료":
                break
            elif self.bread_type not in self.stock:
                print("잘못된 값을 입력했습니다. 모드를 종료합니다.")
                break

            self.bread_count = input("추가할 붕어빵 개수를 입력해주세요 :")
            if self.bread_count == "종료":
                break
            
            try:
                self.bread_count = int(self.bread_count)       
            except ValueError:
                print("잘못된 값을 입력했습니다. 모드를 종료합니다.")
                break

            stock_list = {
                self.bread_type : self.bread_count 
            }
            print("=" * 50)
            print(f"추가하신 재고  : {stock_list}")
            print("=" * 50)
            
            self.stock[self.bread_type] += int(stock_list[self.bread_type])
            
            print(self.stock)
    def calculate_total_sales(self): 
        
        sales_count = {
            "팥붕어빵": 0,
            "슈크림붕어빵": 0,
            "초코붕어빵": 0
        }

        sales_ = {
            "팥붕어빵": 0,
            "슈크림붕어빵": 0,
            "초코붕어빵": 0
        }

        for key in self.order_list:
            sales_count[key] += int(self.order_list[key]) 
        print("=" * 50)
        print(f"주문내역 : {self.order_list} \n")

        total_sales = 0

        for j in sales_:
            sales_[j] = self.price[j] * sales_count[j]

            total_sales += sales_[j]


        print(f"매출 : {sales_}원 \n") 
        print(f"총매출 : {total_sales}원")
        print("=" * 50)

# %% [markdown]
# [과제 2: 초기화 메서드 __init__]
#
# 목표: __init__ 메서드를 구현하여 붕어빵 가게의 초기 재고, 가격, 판매량을 설정합니다.
#
# 설명: self.stock, self.prices, self.sales 딕셔너리를 초기화하세요.
# - stock
#     - "팥붕어빵": 10
#     - "슈크림붕어빵": 8
#     - "초코붕어빵": 5
#
# - prices
#     - "팥붕어빵": 1000
#     - "슈크림붕어빵": 1200
#     - "초코붕어빵": 1500
#
# - sales
#     - "팥붕어빵": 0,
#     - "슈크림붕어빵": 0,
#     - "초코붕어빵": 0

# %%
a = BungeoppangShop(
stock = {
    "팥붕어빵" : 10,
    "슈크림붕어빵" : 8,
    "초코붕어빵" : 5
}

prices = {
    "팥붕어빵" : 1000,
    "슈크림붕어빵" : 1200,
    "초코붕어빵": 15000
}

sales = {
    "팥붕어빵": 0,
    "슈크림붕어빵": 0,
    "초코붕어빵": 0
}
# Out:
#   Cell In[9], line 8
#     prices = {
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# [과제 3: 재고 확인 메서드 check_stock]
#
# 목표: check_stock 함수를 구현하여 현재 붕어빵 재고를 출력합니다.
#
# 설명: self.stock 딕셔너리를 순회하며 각 붕어빵의 종류와 재고를 출력하세요.

# %%
a.check_stock()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 a.check_stock()
#
# NameError: name 'a' is not defined

# %% [markdown]
# [과제 4: 주문 처리 메서드 process_order]
#
# 목표: process_order 함수를 구현하여 손님의 주문을 처리하고 재고를 업데이트합니다.
#
# 설명: bread_type과 bread_count를 매개변수로 받아, 재고를 확인하고 충분한 경우 재고를 감소시키고 판매량을 증가시킵니다. 재고가 부족하거나 잘못된 붕어빵 종류인 경우 적절한 메시지를 출력하세요.

# %%
a.process_order()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 a.process_order()
#
# NameError: name 'a' is not defined

# %% [markdown]
# [과제 5: 관리자 모드 메서드 admin_mode]
#
# 목표: admin_mode 메서드를 구현하여 관리자 모드에서 재고를 추가할 수 있도록 합니다.
#
# 설명: bread_type과 additional_stock을 입력받아 재고를 추가합니다. 잘못된 입력 값이 들어온 경우 적절한 메시지를 출력하세요.

# %%
a.admin_mode()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 a.admin_mode()
#
# NameError: name 'a' is not defined

# %% [markdown]
# [과제 6: 매출 계산 메서드 calculate_total_sales]
#
# 목표: calculate_total_sales 메서드를 구현하여 총 매출을 계산하고 출력합니다.
#
# 설명: self.sales와 self.prices를 사용하여 총 매출을 계산하고 출력하세요.

# %%
a.calculate_total_sales()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 a.calculate_total_sales()
#
# NameError: name 'a' is not defined

# %% [markdown]
# [과제 8: 메인 함수 main]
#
# 목표: main 함수를 작성하여 프로그램의 주요 로직을 실행합니다.
#
# 설명:
# - BungeoppangShop 객체를 생성합니다.
# - 사용자에게 모드를 선택하도록 요청합니다.
# - "주문" 모드에서는 손님의 주문을 처리하고, "관리자" 모드에서는 재고를 추가할 수 있습니다.
# - 프로그램이 종료될 때 총 매출을 계산하고 데이터를 저장합니다.

# %%
def main():
    shop = BungeoppangShop(
        stock ={
            "팥붕어빵": 10,
            "슈크림붕어빵": 8,
            "초코붕어빵": 5
        },
        price ={
            "팥붕어빵": 1000,
            "슈크림붕어빵": 1200,
            "초코붕어빵": 1500
        },
        sales = {
            "팥붕어빵": 0,
            "슈크림붕어빵": 0,
            "초코붕어빵": 0
        }
    )

    while True:
        mode = input(f"{'모드를 선택해주세요. 1.주문 모드 2. 관리자 모드' :^10}")
        if mode == "1":
            shop.process_order()
        elif mode == "2":
            shop.admin_mode()
        elif mode == "종료":
            shop.calculate_total_sales()
            print("프로그램을 종료합니다.")
            break
        else:
            print("1 또는 2를 입력해주세요.(혹은 종료)")
        

main()
    

if __name__ == "__main__":
    main
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 34
#      30         else:
#      31             print("1 또는 2를 입력해주세요.(혹은 종료)")
# ---> 34 main()
#      37 if __name__ == "__main__":
#      38     main
#
# Cell In[6], line 2, in main()
#       1 def main():
# ----> 2     shop = BungeoppangShop(
#       3         stock ={
#       4             "팥붕어빵": 10,
#       5             "슈크림붕어빵": 8,
#       6             "초코붕어빵": 5
#       7         },
#       8         price ={
#       9             "팥붕어빵": 1000,
#      10             "슈크림붕어빵": 1200,
#      11             "초코붕어빵": 1500
#      12         },
#      13         sales = {
#      14             "팥붕어빵": 0,
#      15             "슈크림붕어빵": 0,
#      16             "초코붕어빵": 0
#      17         }
#      18     )
#      20     while True:
#      21         mode = input(f"{'모드를 선택해주세요. 1.주문 모드 2. 관리자 모드' :^10}")
#
# NameError: name 'BungeoppangShop' is not defined
